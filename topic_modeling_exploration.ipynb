# %%
## Import necessary packages
import numpy as np
import pandas as pd
import pyarrow as pa
from sentence_transformers import util , SentenceTransformer
import os

# %%
## Load original dataset and embeddings
eng_175 = pd.read_parquet('./data/eng_175k.parquet')
multi_qa_embeddings = pd.read_parquet('./data/multi_qa_embeddings.parquet').values

## Check by printing type and first 5 rows of each
print(eng_175.head())
print(type(multi_qa_embeddings))
print(multi_qa_embeddings.shape)
print(multi_qa_embeddings[:5,:])
# Out:
#                  id                                              title  \
# 0      math/9907166  Vertex representations via finite groups and t...
# 1      math/9602216  Categoricity and amalgamation for AEC and $ \k...
# 2      math/0504123                       From Loop Groups to 2-Groups
# 3  quant-ph/0401139               Finite Supersymmetry Transformations
# 4      math/0212249         Super black box (formerly: Middle diamond)
#
#                                             abstract update_date  \
# 0    Given a finite group $\Gamma$ and a virtual ...  2023-05-19
# 1    In the original version of this paper, we as...  2023-05-19
# 2    We describe an interesting relation between ...  2023-05-16
# 3    We investigate simple examples of supersymme...  2023-05-09
# 4    This is a slightly corrected version of an o...  2023-05-04
#
#                                       authors_parsed  \
# 0  [['Frenkel', 'Igor', ''], ['Jing', 'Naihuan', ...
# 1  [['Kolman', 'Oren', ''], ['Shelah', 'Saharon',...
# 2  [['Baez', 'John C.', ''], ['Crans', 'Alissa S....
# 3  [['Ilieva', 'Nevena', ''], ['Narnhofer', 'Heid...
# 4                        [['Shelah', 'Saharon', '']]
#
#                                         new_cat
# 0              ['math.QA', 'hep-th', 'math.RT']
# 1                                   ['math.LO']
# 2              ['math.QA', 'hep-th', 'math.DG']
# 3  ['quant-ph', 'hep-th', 'math-ph', 'math.MP']
# 4                                   ['math.LO']
# <class 'numpy.ndarray'>
# (175000, 384)
# [[-0.01767618  0.01758949 -0.05768044 ... -0.04454226  0.12015733
#   -0.00452518]
#  [-0.01760336 -0.05663263  0.04321973 ... -0.09004934 -0.03873408
#    0.06682365]
#  [-0.05105839 -0.0159095  -0.03766153 ... -0.01323472  0.04173296
#   -0.0062279 ]
#  [-0.05798772 -0.09667582 -0.03674868 ... -0.05026176  0.00812556
#    0.01891553]
#  [ 0.00422341  0.07034644 -0.07379991 ... -0.08854556 -0.01541623
#    0.05648737]]

# %%
## Reset the index of the full dataset to make it easy to track what we're doing.
eng_175.reset_index()

## Select first 10,000 entries for a subset to test topic modeling. 
## test_data is the first 10,000 entries of the full dataset eng_175.
## test_embeddings is the corresponding list of embeddings.

test_data = eng_175.iloc[:10000]
test_embeddings = multi_qa_embeddings[:10000,:]

# %%
## Install the component packages
# !pip install umap
# !pip install hdbscan
# Out:
# Collecting umap
#   Downloading umap-0.1.1.tar.gz (3.2 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: umap
#   Building wheel for umap (setup.py): started
#   Building wheel for umap (setup.py): finished with status 'done'
#   Created wheel for umap: filename=umap-0.1.1-py3-none-any.whl size=3551 sha256=75cdf7b706fee0f842d8adc02d1a9ed5cd564131f02b4e5ccfe76d1ef8e70afc
#   Stored in directory: c:\users\leems\appdata\local\pip\cache\wheels\15\f1\28\53dcf7a309118ed35d810a5f9cb995217800f3f269ab5771cb
# Successfully built umap
# Installing collected packages: umap
# Successfully installed umap-0.1.1
# Requirement already satisfied: hdbscan in c:\users\leems\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (0.8.29)
# Requirement already satisfied: cython>=0.27 in c:\users\leems\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from hdbscan) (0.29.34)
# Requirement already satisfied: numpy>=1.20 in c:\users\leems\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from hdbscan) (1.24.2)
# Requirement already satisfied: scipy>=1.0 in c:\users\leems\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from hdbscan) (1.10.1)
# Requirement already satisfied: scikit-learn>=0.20 in c:\users\leems\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from hdbscan) (1.2.2)
# Requirement already satisfied: joblib>=1.0 in c:\users\leems\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from hdbscan) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\leems\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-learn>=0.20->hdbscan) (3.1.0)

# %%
## Install the packages to handle the allenai-specter2 LLM
# !pip install -U adapter-transformers
# Out:
# Collecting adapter-transformers
#   Downloading adapter_transformers-3.2.1-py3-none-any.whl (6.4 MB)
#                                               0.0/6.4 MB ? eta -:--:--
#      --                                       0.4/6.4 MB 10.9 MB/s eta 0:00:01
#      -----                                    0.8/6.4 MB 10.4 MB/s eta 0:00:01
#      --------                                 1.4/6.4 MB 11.4 MB/s eta 0:00:01
#      ------------                             2.0/6.4 MB 11.4 MB/s eta 0:00:01
#      ------------------                       3.0/6.4 MB 12.6 MB/s eta 0:00:01
#      ---------------------                    3.4/6.4 MB 12.2 MB/s eta 0:00:01
#      -------------------------                4.1/6.4 MB 12.5 MB/s eta 0:00:01
#      -------------------------------          5.1/6.4 MB 13.5 MB/s eta 0:00:01
#      -------------------------------------    6.1/6.4 MB 14.4 MB/s eta 0:00:01
#      ---------------------------------------  6.4/6.4 MB 14.6 MB/s eta 0:00:01
#      ---------------------------------------  6.4/6.4 MB 14.6 MB/s eta 0:00:01
#      ---------------------------------------- 6.4/6.4 MB 11.7 MB/s eta 0:00:00
# Requirement already satisfied: filelock in c:\users\leems\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from adapter-transformers) (3.12.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in c:\users\leems\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from adapter-transformers) (0.14.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\leems\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from adapter-transformers) (1.24.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\leems\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from adapter-transformers) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\leems\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from adapter-transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\leems\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from adapter-transformers) (2023.5.5)
# Requirement already satisfied: requests in c:\users\leems\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from adapter-transformers) (2.28.2)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\users\leems\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from adapter-transformers) (0.13.3)
# Requirement already satisfied: tqdm>=4.27 in c:\users\leems\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from adapter-transformers) (4.65.0)
# Requirement already satisfied: fsspec in c:\users\leems\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from huggingface-hub<1.0,>=0.11.0->adapter-transformers) (2023.5.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\leems\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from huggingface-hub<1.0,>=0.11.0->adapter-transformers) (4.5.0)
# Requirement already satisfied: colorama in c:\users\leems\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tqdm>=4.27->adapter-transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\leems\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->adapter-transformers) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\leems\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->adapter-transformers) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\leems\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->adapter-transformers) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\leems\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->adapter-transformers) (2022.12.7)
# Installing collected packages: adapter-transformers
# Successfully installed adapter-transformers-3.2.1

# %%
#from transformers import AutoAdapterModel
from transformers import AutoTokenizer

specter_tokenizer = AutoTokenizer.from_pretrained('allenai/specter2')
#model = AutoAdapterModel.from_pretrained("allenai/specter2")
#adapter_name = model.load_adapter("allenai/specter2_classification", source="hf", set_active=True)

# %%
## Import bertopic as well as its constituent packages
from bertopic import BERTopic
from umap import UMAP
from hdbscan import HDBSCAN

# %%
## Configure our best guess for the optimal representation of the topics
from sklearn.feature_extraction.text import CountVectorizer
from bertopic.representation import MaximalMarginalRelevance
from bertopic.representation import KeyBERTInspired

vectorizer = CountVectorizer(stop_words='english',ngram_range=(2,2))
representation_model = MaximalMarginalRelevance(diversity=1)

# %%
## Create topic model with these representation parameters, topic size = 20
model = BERTopic(
    min_topic_size=20,verbose=True,vectorizer_model=vectorizer,representation_model=representation_model)

# %%
## Fit the model on the test set and generate topics
## First Retrieve the string of documents fit
docs = (test_data['title'] + test_data['abstract']).to_list()
topics , probs = model.fit_transform(documents=docs,embeddings=test_embeddings)
# Out:
# 2023-05-28 19:14:38,318 - BERTopic - Reduced dimensionality
# 2023-05-28 19:14:39,997 - BERTopic - Clustered reduced embeddings
# C:\Users\Leems\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\bertopic\representation\_mmr.py:61: UserWarning: MaximalMarginalRelevance can only be used BERTopic was instantiatedwith the `embedding_model` parameter.
#   warnings.warn("MaximalMarginalRelevance can only be used BERTopic was instantiated"

# %%
model.generate_topic_labels(nr_words=10)
# Out:
# ['-1_differential equations_paper study_numerical experiments_partial differential_dynamical systems_boundary conditions_neural networks_optimization problems_upper bound_machine learning',
#  '0_chromatic number_maximum degree_graph vertices_minimum degree_random graphs_vertex set_random graph_complete graph_power graph_induced subgraph',
#  '1_moduli spaces_moduli space_elliptic curves_abelian varieties_smooth projective_del pezzo_elliptic curve_number field_vector bundles_rigid analytic',
#  '2_simulation results_reconfigurable intelligent_massive mimo_multiple access_mimo systems_multipleinput multipleoutput_channel estimation_numerical results_channel state_base station',
#  '3_composition operators_banach spaces_sobolev spaces_multiplication operators_weighted composition_banach space_bloch space_bergman spaces_operator norm_weighted bergman',
#  '4_random variables_brownian motion_limit theorem_central limit_limit theorems_large deviation_random walk_deviation principle_markov process_weak convergence',
#  '5_finite element_discontinuous galerkin_element method_galerkin method_error estimates_numerical experiments_element methods_finite volume_finite difference_numerical results',
#  '6_reinforcement learning_vehicle routing_routing problem_optimal power_resource allocation_mixedinteger linear_power flow_optimization problem_case study_dynamic programming',
#  '7_set theory_lie complexity_proof schemata_definable types_real numbers_modal logics_sectional complement_semimodular lattices_fan theorem_firstorder logic',
#  '8_lie algebras_lie algebra_nilpotent lie_relative rotabaxter_graded lie_cohomology theory_lie superalgebras_lie superalgebra_finite dimensional_transposed poisson',
#  '9_euler equations_initial data_weak solutions_navierstokes equations_global existence_compressible navierstokes_compressible euler_strong solutions_boundary condition_wave equation',
#  '10_gradient descent_convergence rate_optimization problems_stochastic gradient_machine learning_global convergence_proposed algorithm_objective function_linear convergence_convergence analysis',
#  '11_linear codes_locally repairable_rm codes_mds codes_ldpc codes_error correction_repairable codes_quantum codes_quantum error_minimum distance',
#  '12_schrodinger operators_trace formula_magnetic field_random matrices_schrodinger operator_magnetic laplacian_selfadjoint extensions_dirac operator_correlation matrix_dirichlet series',
#  '13_optimal control_control problem_control problems_control systems_model predictive_predictive control_control barrier_barrier functions_optimality conditions_existence optimal',
#  '14_monte carlo_treatment effect_maximum likelihood_test statistic_asymptotic normality_real data_model parameters_treatment effects_sample size_posterior distribution',
#  '15_module category_derived category_tensor product_tilting subcategories_tilting subcategory_category modules_polynomial functors_nmathbbzcluster tilting_grothendieck category_module categories',
#  '16_elliptic equations_nonlinear elliptic_free boundary_elliptic systems_weak solutions_dirichlet problem_elliptic equation_boundary conditions_parabolic equations_double phase',
#  '17_nonlinear schrodinger_schrodinger equation_schrodinger equations_cauchy problem_initial data_strichartz estimates_normalized solutions_soliton solutions_ground states_solitonic regions',
#  '18_arithmetic progressions_positive integers_prime numbers_sv1 cdots_fibonacci numbers_positive integer_short intervals_primes arithmetic_mathbfx bbn_perfect cuboid',
#  '19_singular value_value decomposition_regularization parameter_gravity magnetic_magnetic data_unbiased predictive_inversion gravity_predictive risk_randomized singular_joint inversion',
#  '20_neural networks_neural network_deep neural_physicsinformed neural_differential equations_activation functions_physics informed_informed neural_weight similarity_partial differential',
#  '21_slice genus_floer homology_rational homology_topological slice_folded ribbonlength_folded ribbon_torus knots_concordance group_knot complements_instanton homology',
#  '22_finitely generated_automorphism group_solvable groups_finite groups_finite group_schreier growth_finitely presented_automorphism groups_simple groups_free groups',
#  '23_scalar curvature_ricci curvature_ricci flow_curvature operator_riemannian manifolds_operator second_second kind_riemannian metrics_riemann soliton_compact homogeneous',
#  '24_mean field_field games_field game_nash equilibrium_mixed strategy_nash equilibria_zerodeterminant strategies_common noise_markov games_strategy equilibrium',
#  '25_lagrangian submanifolds_minimal symplectic_homotopy comomentum_symplectic fillings_comomentum map_fukaya category_seibergwitten invariant_monopole floer_floer cohomology_deformation space',
#  '26_gauge fixing_field theory_gauge theory_gauge theories_cs theory_yangmills theory_invertible topological_lagrange densities_general relativity_gauge symmetry',
#  '27_hausdorff dimension_fractal interpolation_interpolation function_mean hausdorff_local dimensions_vectorvalued fractal_fractal dimension_lower upper_dimension functions_potential singular',
#  '28_modular forms_cusp forms_maass forms_siegel modular_forms weight_theta functions_stable klingen_hecke eigenvalues_eisenstein series_cusp form',
#  '29_congruence classes_sequentially congruent_congruent partitions_partition diamonds_congruence family_plane partition_congruences modulo_generating function_partition function_partition rank',
#  '30_number fields_number field_unary forms_algebraic numbers_quadratic fields_perfect unary_rational functions_continued fraction_continued fractions_totally real',
#  '31_zeta function_riemann zeta_riemann hypothesis_mobius function_sump leq_hypergeometric functions_riemann zetafunction_partial sums_lagarias criterion_xc right',
#  '32_injective monotones_permutations sn_layered permutation_long cycles_denote set_quantum complexity_realvalued monotones_preordered spaces_positional marked_transposition array',
#  '33_kahler manifolds_ricci curvature_kahler metrics_kahler metric_conformally kahler_toric manifolds_vaisman manifolds_kahler geometry_abelian lie_compact kahler',
#  '34_lattice boltzmann_effective viscosity_relaxation time_heat conduction_steady state_time filter_immersed peridynamics_liquid crystal_boundary conditions_navierstokes equations',
#  '35_intersection balls_lattice polytope_point sets_lower bound_inversive distance_2d1 vertices_inscribed rectangles_lebesgue number_convex position_distance fixed',
#  '36_hopf algebras_hopf algebra_pointed hopf_algebras dimension_hopf cyclic_nichols algebras_cyclic cohomology_dimension 16_left counital_yetterdrinfeld modules',
#  '37_topological entropy_structural entropy_entanglement entropy_entropy formula_shannon entropy_relative entropy_random dynamical_conditional entropy_quantum conditional_quantum relative',
#  '38_tutte polynomial_areaminimizing cones_flag matroids_oriented matroids_positroid varieties_rainbow bases_covering grassmannian_elastic elements_field polytopes_oriented real',
#  '39_chern character_compact kahler_kahler manifolds_complex manifolds_dirac structures_characteristic classes_vector bundles_complex structures_compact complex_meromorphic 1forms',
#  '40_transition pathway_probable transition_dynamical systems_koopman operator_critical transitions_bacterial density_model reduction_recurrent neural_training data_latent space',
#  '41_hyperbolic groups_relatively hyperbolic_hyperbolic group_finitely generated_bloch transform_rightangled coxeter_parabolic subgroups_mapping class_acylindrically hyperbolic_gelfanddickey hierarchy',
#  '42_braid group_braid groups_mapping class_class groups_virtual singular_graph braid_virtual twin_braid graphs_singular braid_bounded cohomology',
#  '43_blowup solutions_finite time_blowup solution_blowup profile_finite blowup_jeans instability_swifthohenberg equation_timescale systems_selfsimilar blowup_blowup points',
#  '44_persistent homology_persistence modules_extended persistence_persistence diagrams_persistence diagram_persistence module_topological data_betti numbers_data analysis_contagion maps',
#  '45_minimal hypersurfaces_hyperbolic manifolds_twist knot_hyperbolic 3manifold_totally geodesic_bounds change_hyperbolic domains_gausskronecker curvature_euclidean traveller_parabolic minimal',
#  '46_starlike functions_analytic capacity_hankel determinant_functions associated_analytic functions_shaped domain_associated petal_continuous analytic_functions symmetrized_hankel determinants',
#  '47_inverse semigroup_soft quasigroup_inverse semigroups_totally disconnected_mathcal cclosed_soft quasigroups_semigroup injectively_injectively mathcal_left right_semigroup compactification',
#  '48_hochschild homology_topological hochschild_algebraic ktheory_stiefel manifolds_spectral sequence_homotopy theory_isotropic stable_steenrod algebra_homotopy groups_cohomology groups']

# %%
model.get_topic_freq()
# Out:
#     Topic  Count
# 0      -1   5337
# 1       0    593
# 2       1    347
# 3       2    308
# 4       3    258
# 5       4    235
# 6       5    185
# 7       6    160
# 8       7    156
# 9       8    153
# 10      9    148
# 11     10    147
# 13     11    133
# 12     12    133
# 14     13    121
# 15     14    120
# 16     15     94
# 17     16     86
# 18     17     83
# 19     18     74
# 20     19     74
# 21     20     69
# 22     21     67
# 23     22     64
# 24     23     62
# 25     24     52
# 26     25     51
# 27     26     48
# 28     27     45
# 29     28     39
# 30     29     39
# 31     30     37
# 32     31     37
# 33     32     33
# 34     33     32
# 35     34     31
# 36     35     30
# 37     36     30
# 38     37     29
# 39     38     28
# 40     39     27
# 41     40     26
# 42     41     25
# 43     42     24
# 44     43     23
# 45     44     22
# 46     45     22
# 47     46     22
# 48     47     21
# 49     48     20

# %% [markdown]
# ### Summary
#
# 1. Roughly half of the documents are unclassified with min topic size = 20
# 1. 2 and 3 grams result in less 'common' or 'math stop words' appearing in topic descriptions, more technical words.
# 1. What happens when we play with the UMAP model itself?

# %%
## Changing the UMAP model
