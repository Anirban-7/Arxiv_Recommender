# %%
# !pip install bertopic
# !pip install arxiv
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting bertopic
#   Downloading bertopic-0.15.0-py2.py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.4/143.4 kB 9.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.22.4)
# Collecting hdbscan>=0.8.29 (from bertopic)
#   Downloading hdbscan-0.8.29.tar.gz (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 99.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting umap-learn>=0.5.0 (from bertopic)
#   Downloading umap-learn-0.5.3.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 kB 10.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.5.3)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.2.2)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (4.65.0)
# Collecting sentence-transformers>=0.4.1 (from bertopic)
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 10.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (5.13.1)
# Requirement already satisfied: cython>=0.27 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (0.29.34)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (1.10.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2022.7.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic) (8.2.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2.post1->bertopic) (3.1.0)
# Collecting transformers<5.0.0,>=4.6.0 (from sentence-transformers>=0.4.1->bertopic)
#   Downloading transformers-4.29.2-py3-none-any.whl (7.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 97.6 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.15.2+cu118)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (3.8.1)
# Collecting sentencepiece (from sentence-transformers>=0.4.1->bertopic)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 75.2 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.4.0 (from sentence-transformers>=0.4.1->bertopic)
#   Downloading huggingface_hub-0.15.1-py3-none-any.whl (236 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 21.7 MB/s eta 0:00:00
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.10/dist-packages (from umap-learn>=0.5.0->bertopic) (0.56.4)
# Collecting pynndescent>=0.5 (from umap-learn>=0.5.0->bertopic)
#   Downloading pynndescent-0.5.10.tar.gz (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 72.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.12.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2023.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.27.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (23.1)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (67.7.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.1.5->bertopic) (1.16.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (16.0.5)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (2022.10.31)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 116.6 MB/s eta 0:00:00
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers>=0.4.1->bertopic) (8.1.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence-transformers>=0.4.1->bertopic) (8.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (2.1.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (1.3.0)
# Building wheels for collected packages: hdbscan, sentence-transformers, umap-learn, pynndescent
#   Building wheel for hdbscan (pyproject.toml) ... done
#   Created wheel for hdbscan: filename=hdbscan-0.8.29-cp310-cp310-linux_x86_64.whl size=3541995 sha256=c7019779dabbe2951dd4bd3ab04c827301bf0f85988ddede3f94daed90c91333
#   Stored in directory: /root/.cache/pip/wheels/dc/52/e3/6c6b60b126b4d5c4370cb5ac071b82950f91649d62d72f7f56
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125926 sha256=57a7cbe4467c277fdd4f08d3447399505bde6b4dc75f41240b959150495aa33c
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82816 sha256=500fa0d8d8aa152daa046f78683d557456581a2199e3111549d604815d978e16
#   Stored in directory: /root/.cache/pip/wheels/a0/e8/c6/a37ea663620bd5200ea1ba0907ab3c217042c1d035ef606acc
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.10-py3-none-any.whl size=55622 sha256=6245d96bb75162693ffb43aaa6c9b4bb91eca77f156655369b0735dbdf111e5c
#   Stored in directory: /root/.cache/pip/wheels/4a/38/5d/f60a40a66a9512b7e5e83517ebc2d1b42d857be97d135f1096
# Successfully built hdbscan sentence-transformers umap-learn pynndescent
# Installing collected packages: tokenizers, sentencepiece, huggingface-hub, transformers, pynndescent, hdbscan, umap-learn, sentence-transformers, bertopic
# Successfully installed bertopic-0.15.0 hdbscan-0.8.29 huggingface-hub-0.15.1 pynndescent-0.5.10 sentence-transformers-2.2.2 sentencepiece-0.1.99 tokenizers-0.13.3 transformers-4.29.2 umap-learn-0.5.3
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting arxiv
#   Downloading arxiv-1.4.7-py3-none-any.whl (12 kB)
# Collecting feedparser (from arxiv)
#   Downloading feedparser-6.0.10-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.1/81.1 kB 6.6 MB/s eta 0:00:00
# Collecting sgmllib3k (from feedparser->arxiv)
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: sgmllib3k
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6046 sha256=3bbb6ef0281013d71abdf4650793d2ed35c93da0d75ee5cae88bc86dc5c2e62e
#   Stored in directory: /root/.cache/pip/wheels/f0/69/93/a47e9d621be168e9e33c7ce60524393c0b92ae83cf6c6e89c5
# Successfully built sgmllib3k
# Installing collected packages: sgmllib3k, feedparser, arxiv
# Successfully installed arxiv-1.4.7 feedparser-6.0.10 sgmllib3k-1.0.0

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

import os
import pandas as pd
import numpy as np
from bertopic import BERTopic
import arxiv
from sklearn.feature_extraction.text import CountVectorizer
from umap import UMAP
from hdbscan import HDBSCAN

from google.colab import drive

drive.mount('/content/drive')
os.chdir('/content/drive/MyDrive/Arxiv_Recommender')
# !pwd
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Arxiv_Recommender

# %%
import sys
sys.path.append('')
from data_utils import clean_data

# %%
def results_to_df(query_results):
  drop_cols = ['authors','links','_raw']
  df = pd.DataFrame()

  for result in query_results:
      row_dict = {k : v for (k,v) in vars(result).items() if k not in drop_cols}
      row_dict['authors'] = ','.join([author.name for author in result.authors])
      row = pd.Series(row_dict)
      df = pd.concat([df , row.to_frame().transpose()], axis = 0)

  return df.reset_index(drop=True,inplace=False)

# %% [markdown]
# # - train the optimal BERTopic model -

# %%
df_lib = pd.read_parquet('data/raw_data/filter_20k.parquet')
lib_vecs = pd.read_parquet('data/vector_embeddings/df_lib_vecs_20k_sbert.parquet').values
lib_abs = (df_lib.title + ' ' +  df_lib.abstract).to_list()
len(lib_abs)
# Out:
# 20000

# %%
vectorizer_model = CountVectorizer(ngram_range=(2, 3), 
                                   stop_words="english")
umap_model = UMAP(n_neighbors=5, 
                      n_components=5,
                      min_dist = 0, 
                      metric='cosine', 
                      random_state = 623,
                      low_memory=False)
bertopic_model = BERTopic(embedding_model = 'all-MiniLM-L6-v2',
                              umap_model = umap_model,
                              vectorizer_model=vectorizer_model, 
                              calculate_probabilities=True,
                              verbose = True)

# %%
lib_topics, lib_probs = bertopic_model.fit_transform(lib_abs, lib_vecs)
# Out:
# Downloading (…)e9125/.gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)7e55de9125/README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading (…)55de9125/config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading (…)125/data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading (…)e9125/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading (…)9125/train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading (…)7e55de9125/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)5de9125/modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# 2023-06-03 00:00:47,283 - BERTopic - Reduced dimensionality
# 2023-06-03 00:03:12,360 - BERTopic - Clustered reduced embeddings

# %%
df_lib_topic_freqs = bertopic_model.get_topic_freq()
df_topic_info = bertopic_model.get_topic_info()
n_topics = df_lib_topic_freqs['Topic'].shape[0]

# %%
new_topics = bertopic_model.reduce_outliers(lib_abs, lib_topics, probabilities=lib_probs, 
                             threshold=0.05, strategy="probabilities")
bertopic_model.update_topics(lib_abs, topics=new_topics)

# %% [markdown]
# # - one to one arxiv recommender using BERTopic -

# %%
# euclidean norm
def norm(vec):
  return np.sqrt((vec**2).sum())

# cosine similarity function
def cos_sim(vec1,vec2):
  return (vec1 * vec2).sum()/(norm(vec1)*norm(vec2))

def get_title_abstracts(ids) :
  results =  arxiv.Search(id_list = ids).results()
  abstracts = []
  for result in results :
    abstracts.append(clean_data(result.title + ' ' + result.summary))
  return abstracts

def stratify_by_topics(df, vecs, topic_labels, n_topics) :
  # dfs_by_topics : a list where the ith entry is the sub-dataframe of df with topic i
  # arrs_by_topics : a list where the ith entry is the vector embedding 
  dfs_by_topics = []
  vecs_by_topics = []
  for i in range(n_topics) :
    idxs = [k for k,topic in enumerate(topic_labels) if topic == i]
    if idxs :
      dfs_by_topics.append(df.iloc[idxs])
      vecs_by_topics.append(vecs[idxs])
    else :
      dfs_by_topics.append(pd.DataFrame())
      vecs_by_topics.append(np.array([]))
  return dfs_by_topics, vecs_by_topics


def one_on_one_recommender(user_vecs,user_topics,lib_dfs_by_topics,lib_vecs_by_topics, df_topic_info) :
  papers_to_recommend =[]
  for i in range(user_vecs.shape[0]):
    # this part is unnecessary but I'm doing this to simplify notations
    # vector representing ith paper in the user input 
    user_vec = user_vecs[i].reshape(1,-1)
    # the topic index that ith paper in the user input belongs to
    user_topic = user_topics[i]

    # compute cosine similarity scores between ith paper in the user input and 
    # the daily papers(the papers we will recommend from) with the topic == user_topic
    sim_scores = [cos_sim(user_vec, vec) for vec in lib_vecs_by_topics[user_topic]]
    # check whether daily papers with topic == user_topic is empty or not
    if sim_scores :
      # if daily papers with topic == user_topic is not empty
      # append the title of the daily paper with highest similarity score with ith paper in the user input
      argmax = max(enumerate(sim_scores), key=lambda x: x[1])[0]
      papers_to_recommend.append(pd.DataFrame({'categories' : df_topic_info['Name'].iloc[user_topic+1],
                                               'title' : lib_dfs_by_topics[user_topic].iloc[argmax].title, 
                                               'summary' :lib_dfs_by_topics[user_topic].iloc[argmax].abstract},
                                              index = [i]))
    else : 
      # if daily papers with topic == user_topic is empty 
      papers_to_recommend.append(pd.DataFrame({},index = [i]))
  return pd.concat(papers_to_recommend, axis = 0)

# %%
ethan = ['1802.03426', '2304.14481', '2303.03190', '2210.13418',
         '2210.12824', '2210.00661', '2007.02390', '1808.05860',
         '2005.12732','1804.05690']
jeeuhn = ['0905.0486', 'math/0006187', '2106.07444', '1402.0490', 
          '1512.08942', '1603.09235', 'math/0510265', 'math/0505056', 
          'math/0604379', '2209.02568']
mike = ['2207.13571','2207.13498','2211.09644','2001.10647',
        '2103.08093','2207.08245', '2207.01677','2205.08744',
        '2008.04406','1912.09845']
jenia = ['2010.14967', '1307.0493', 'quant-ph/0604014', '2201.05140', 
         '1111.1877', 'quant-ph/9912054', '1611.08286', '1507.02858', 
         'math-ph/0107001','1511.01241', 'math-ph/9904020', '2211.15336', 
         '2212.03719']

# %% [markdown]
# # Ethan

# %%
lib_dfs_by_topics, lib_vecs_by_topics = stratify_by_topics(df_lib, lib_vecs, lib_topics, n_topics)

# %%
user_input_ids = ethan

user_abs = get_title_abstracts(user_input_ids)

# convert the list of abstracts of user input papers into vectors using
# sBERT inside the trained BERTopic model(i.e. topic_model) 
user_vecs = bertopic_model.embedding_model.embed(user_abs)

# inference the topics that the user input papers belong to
user_topics,_ = bertopic_model.transform(user_abs)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2023-06-03 00:44:06,678 - BERTopic - Reduced dimensionality
# 2023-06-03 00:44:06,794 - BERTopic - Calculated probabilities with HDBSCAN
# 2023-06-03 00:44:06,795 - BERTopic - Predicted clusters

# %%
print('For the following input papers :')
display(results_to_df(arxiv.Search(id_list = user_input_ids).results())[['categories','title','summary']])
# Out:
# For the following input papers :
#                                           categories  \
# 0                            [stat.ML, cs.CG, cs.LG]
# 1                                          [math.GT]
# 2                                 [math.GT, math.CO]
# 3                                 [math.GT, math.DS]
# 4                                          [math.GR]
# 5                                          [math.GT]
# 6                   [math.AT, physics.soc-ph, 55N31]
# 7  [physics.soc-ph, math.MG, 91D20 (Primary), 05C...
# 8       [cs.SI, cs.CY, math.CO, 05C90, 05C70, 05C85]
# 9           [math.GT, math.DS, 37B10, 57M50, 58J50,]
#
#                                                title  \
# 0  UMAP: Uniform Manifold Approximation and Proje...
# 1  Endperiodic maps, splitting sequences, and bra...
# 2     Train track combinatorics and cluster algebras
# 3  Standardly embedded train tracks and pseudo-An...
# 4                    Class number for pseudo-Anosovs
# 5  Braids, entropies and fibered 2-fold branched ...
# 6    The (homological) persistence of gerrymandering
# 7          Discrete geometry for electoral geography
# 8  Mathematics of Nested Districts: The Case of A...
# 9  You can hear the shape of a billiard table: Sy...
#
#                                              summary
# 0  UMAP (Uniform Manifold Approximation and Proje...
# 1  We strengthen the unpublished theorem of Gabai...
# 2  The concepts of train track was introduced by ...
# 3  We show that given a fully-punctured pseudo-An...
# 4  Given two automorphisms of a group $G$, one is...
# 5  It is proved by Sakuma and Brooks that any clo...
# 6  We apply persistent homology, the dominant too...
# 7  We discuss the "compactness," or shape analysi...
# 8  In eight states, a "nesting rule" requires tha...
# 9  We give a complete characterization of the rel...

# %%
print('We recommend :')
display(one_on_one_recommender(user_vecs,user_topics,lib_dfs_by_topics,lib_vecs_by_topics,df_topic_info))
# Out:
# We recommend :
#                                           categories  \
# 0                                                NaN
# 1                                                NaN
# 2  92_morse function_abstract weak_morse function...
# 3  92_morse function_abstract weak_morse function...
# 4  138_partially hyperbolic_anosov flows_divergen...
# 5                                                NaN
# 6                                                NaN
# 7  233_brownian map_branched coverings_real branc...
# 8                                                NaN
# 9  47_outer billiard_periodic trajectories_period...
#
#                                                title  \
# 0                                                NaN
# 1                                                NaN
# 2  Laminations and 2filling rays on infinite type...
# 3  A Linking/ Equivariant Variational Argument in...
# 4  Anomalous partially hyperbolic diffeomorphisms...
# 5                                                NaN
# 6                                                NaN
# 7  Scaling Limit of Random Planar Quadrangulation...
# 8                                                NaN
# 9  You can hear the shape of a billiard table: Sy...
#
#                                              summary
# 0                                                NaN
# 1                                                NaN
# 2    The loop graph of an infinite type surface i...
# 3    Let  be a contact form on , let  be its Reeb...
# 4    Let  be a closed 3manifold which admits an A...
# 5                                                NaN
# 6                                                NaN
# 7    We discuss the scaling limit of large planar...
# 8                                                NaN
# 9    We give a complete characterization of the r...

# %% [markdown]
# # Jeeuhn

# %%
user_input_ids = jeeuhn
#users_input_ids = mike
#users_input_ids = jenia

user_abs = get_title_abstracts(user_input_ids)

# convert the list of abstracts of user input papers into vectors using
# sBERT inside the trained BERTopic model(i.e. topic_model) 
user_vecs = bertopic_model.embedding_model.embed(user_abs)

# inference the topics that the user input papers belong to
user_topics,_ = bertopic_model.transform(user_abs)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2023-06-03 00:44:08,436 - BERTopic - Reduced dimensionality
# 2023-06-03 00:44:08,570 - BERTopic - Calculated probabilities with HDBSCAN
# 2023-06-03 00:44:08,571 - BERTopic - Predicted clusters

# %%
print('For the following input papers :')
display(results_to_df(arxiv.Search(id_list = user_input_ids).results())[['categories','title','summary']])
# Out:
# For the following input papers :
#                              categories  \
# 0      [math.GT, math.AG, 17B10, 57T10]
# 1                             [math.AG]
# 2           [math.RT, math.AG, math.QA]
# 3           [math.SG, math.AG, math.GT]
# 4  [math.SG, math.AG, math.CO, math.GT]
# 5           [math.AG, math.AT, math.RT]
# 6             [math.GT, math.QA, 57M25]
# 7             [math.QA, math.GT, 57M25]
# 8           [math.SG, math.GT, math.RT]
# 9                    [math.AG, math.RT]
#
#                                                title  \
# 0  A geometric construction of colored HOMFLYPT h...
# 1  The Hard Lefschetz Theorem and the topology of...
# 2     From the Hecke Category to the Unipotent Locus
# 3         Legendrian knots and constructible sheaves
# 4            Cluster varieties from Legendrian knots
# 5  The Hodge theory of the Decomposition Theorem ...
# 6  Triply-graded link homology and Hochschild hom...
# 7         Matrix factorizations and link homology II
# 8      Constructible Sheaves and the Fukaya Category
# 9           The $P=W$ conjecture for $\mathrm{GL}_n$
#
#                                              summary
# 0  The aim of this paper is two-fold. First, we g...
# 1  We introduce the notion of lef line bundles on...
# 2  Let $W$ be the Weyl group of a split semisimpl...
# 3  We study the unwrapped Fukaya category of Lagr...
# 4  Many interesting spaces --- including all posi...
# 5  In its simplest form the Decomposition Theorem...
# 6  We trade matrix factorizations and Koszul comp...
# 7  To a presentation of an oriented link as the c...
# 8  Let $X$ be a compact real analytic manifold, a...
# 9  We prove the $P=W$ conjecture for $\mathrm{GL}...

# %%
print('We recommend :')
display(one_on_one_recommender(user_vecs,user_topics,lib_dfs_by_topics,lib_vecs_by_topics,df_topic_info))
# Out:
# We recommend :
#                                           categories  \
# 0  129_quantum field_topological quantum_quantum ...
# 1  12_moduli space_higgs bundles_moduli spaces_li...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  12_moduli space_higgs bundles_moduli spaces_li...
# 6  7_vertex operator_conformal field_vertex opera...
# 7  129_quantum field_topological quantum_quantum ...
# 8                                                NaN
# 9                                                NaN
#
#                                                title  \
# 0  On ambiguity in knot polynomials for virtual k...
# 1  Log Picard algebroids and meromorphic line bun...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5   On a result of Gelfand, Kapranov, and Zelevinsky
# 6              Multilinear forms and graded algebras
# 7  On ambiguity in knot polynomials for virtual k...
# 8                                                NaN
# 9                                                NaN
#
#                                              summary
# 0    We claim that HOMFLY polynomials for virtual...
# 1    We introduce logarithmic Picard algebroids, ...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5    In this paper I give new elementary proofs o...
# 6    In this paper we investigate the class of th...
# 7    We claim that HOMFLY polynomials for virtual...
# 8                                                NaN
# 9                                                NaN

# %% [markdown]
# # Michael

# %%
user_input_ids = mike

user_abs = get_title_abstracts(user_input_ids)

# convert the list of abstracts of user input papers into vectors using
# sBERT inside the trained BERTopic model(i.e. topic_model) 
user_vecs = bertopic_model.embedding_model.embed(user_abs)

# inference the topics that the user input papers belong to
user_topics,_ = bertopic_model.transform(user_abs)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2023-06-03 00:44:10,097 - BERTopic - Reduced dimensionality
# 2023-06-03 00:44:10,209 - BERTopic - Calculated probabilities with HDBSCAN
# 2023-06-03 00:44:10,211 - BERTopic - Predicted clusters

# %%
print('For the following input papers :')
display(results_to_df(arxiv.Search(id_list = user_input_ids).results())[['categories','title','summary']])
# Out:
# For the following input papers :
#                                           categories  \
# 0                        [math-ph, math.MP, math.SP]
# 1                                 [math.SP, math.AP]
# 2                   [math.AP, math.SP, 35P20, 58J50]
# 3                     [math.AP, 58J40, 35A23, 58K35]
# 4               [math.AP, math-ph, math.MP, math.SP]
# 5               [math.SP, math-ph, math.AP, math.MP]
# 6                        [math-ph, math.MP, math.SP]
# 7                        [math.AP, math.DG, math.SP]
# 8  [math-ph, math.MP, 81Q20 (Primary), 35S30 (Sec...
# 9                                          [math.AP]
#
#                                                title  \
# 0   Scaling asymptotics of spectral Wigner functions
# 1  $2$-nodal domain theorems for higher dimension...
# 2  Asymptotics for the spectral function on Zoll ...
# 3        Caustics of weakly Lagrangian distributions
# 4                          Around quantum ergodicity
# 5  Classical Wave methods and modern gauge transf...
# 6  Scaling Asymptotics of Wigner Distributions of...
# 7               A proof of a Melrose's trace formula
# 8                      Reduction and Coherent States
# 9  An introduction to microlocal complex deformat...
#
#                                              summary
# 0  We prove that smooth Wigner-Weyl spectral sums...
# 1  We prove that the real parts of equivariant (b...
# 2  On a smooth, compact, Riemannian manifold with...
# 3  We study semiclassical sequences of distributi...
# 4  We discuss Shnirelman's Quantum Ergodicity The...
# 5  In this article, we consider the asymptotic be...
# 6  The main result of this article gives scaling ...
# 7  We give a new proof ofan extension of the Chaz...
# 8  We apply a quantum version of dimensional redu...
# 9  In this expository article we relate the prese...

# %%
print('We recommend :')
display(one_on_one_recommender(user_vecs,user_topics,lib_dfs_by_topics,lib_vecs_by_topics,df_topic_info))
# Out:
# We recommend :
#                                           categories  \
# 0  0_random matrices_random matrix_random matrix ...
# 1  18_lie group_riemannian foliations_singular ri...
# 2  216_random waves_arithmetic random waves_excis...
# 3  11_schr odinger_odinger operators_schr odinger...
# 4                                                NaN
# 5  11_schr odinger_odinger operators_schr odinger...
# 6  0_random matrices_random matrix_random matrix ...
# 7  68_index theorem_dirac operator_pseudodifferen...
# 8                                                NaN
# 9                                                NaN
#
#                                                title  \
# 0  Uniform Semiclassical Approximation for the Wi...
# 1    A diameter gap for quotients of the unit sphere
# 2  Mean of the norm for normalized random waves o...
# 3  Weyl law for semiclassical resonances with ran...
# 4                                                NaN
# 5     Short Loops and Pointwise Spectral Asymptotics
# 6  Uniform Semiclassical Approximation for the Wi...
# 7           Logarithmic Trace of Toeplitz Projectors
# 8                                                NaN
# 9                                                NaN
#
#                                              summary
# 0    A new uniform asymptotic approximation for t...
# 1    We prove that for any isometric action of a ...
# 2    This article concerns upper bounds for norms...
# 3    In this work we consider semiclassical Schr\...
# 4                                                NaN
# 5    We consider pointwise semiclassical spectral...
# 6    A new uniform asymptotic approximation for t...
# 7    We prove that the trace of the logarithmic t...
# 8                                                NaN
# 9                                                NaN

# %% [markdown]
# # Jenia

# %%
user_input_ids = jenia

user_abs = get_title_abstracts(user_input_ids)

# convert the list of abstracts of user input papers into vectors using
# sBERT inside the trained BERTopic model(i.e. topic_model) 
user_vecs = bertopic_model.embedding_model.embed(user_abs)

# inference the topics that the user input papers belong to
user_topics,_ = bertopic_model.transform(user_abs)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2023-06-03 00:44:12,383 - BERTopic - Reduced dimensionality
# 2023-06-03 00:44:12,539 - BERTopic - Calculated probabilities with HDBSCAN
# 2023-06-03 00:44:12,540 - BERTopic - Predicted clusters

# %%
print('For the following input papers :')
display(results_to_df(arxiv.Search(id_list = user_input_ids).results())[['categories','title','summary']])
# Out:
# For the following input papers :
#                                            categories  \
# 0                [math.AP, math-ph, math.MP, math.SP]
# 1    [math-ph, math.MP, math.SG, 37J05, 81S10, 53C55]
# 2                        [quant-ph, math-ph, math.MP]
# 3                [quant-ph, hep-th, math-ph, math.MP]
# 4                        [math-ph, math.MP, quant-ph]
# 5                        [quant-ph, math-ph, math.MP]
# 6                                          [quant-ph]
# 7    [math-ph, math.MP, math.NA, 42C05, 81Q12, 81S10]
# 8                [math-ph, hep-th, math.MP, quant-ph]
# 9           [math.AP, math-ph, math.MP, 58J40, 81Q20]
# 10  [math-ph, math.AG, math.CV, math.MP, math.PR, ...
# 11                                [quant-ph, nlin.CD]
# 12                       [quant-ph, math-ph, math.MP]
#
#                                                 title  \
# 0   Construction of quasimodes for non-selfadjoint...
# 1   The exponential map of the complexification of...
# 2   Time evolution of non-Hermitian Hamiltonian sy...
# 3   An introduction to PT-symmetric quantum mechan...
# 4   Complexified coherent states and quantum evolu...
# 5         Holomorphic Methods in Mathematical Physics
# 6   Unitarity of the time-evolution and observabil...
# 7   Non-Hermitian propagation of Hagedorn wavepackets
# 8   Pseudo-Hermiticity versus PT Symmetry: The nec...
# 9   Semiclassical states associated to isotropic s...
# 10  Universality and scaling of correlations betwe...
# 11  Semiclassical Husimi distributions for non-Her...
# 12  Husimi dynamics generated by non-Hermitian Ham...
#
#                                               summary
# 0   We construct quasimodes for some non-selfadjoi...
# 1   Let $(M, \omega, J)$ be a K\"ahler manifold an...
# 2   We provide time-evolution operators, gauge tra...
# 3   I will provide a pedagogical introduction to n...
# 4   The complex geometry underlying the Schr\"odin...
# 5   This set of lecture notes gives an introductio...
# 6   Here we present an strategy for the derivation...
# 7   We investigate the time evolution of Hagedorn ...
# 8   We introduce the notion of pseudo-Hermiticity ...
# 9   We define classes of quantum states associated...
# 10  We study the limit as $N\to\infty$ of the corr...
# 11  We construct a semiclassical phase-space densi...
# 12  The dynamics generated by non-Hermitian Hamilt...

# %%
print('We recommend :')
display(one_on_one_recommender(user_vecs,user_topics,lib_dfs_by_topics,lib_vecs_by_topics,df_topic_info))
# Out:
# We recommend :
#                                            categories  \
# 0                                                 NaN
# 1   75_quaternionic contact_complex structures_qua...
# 2                                                 NaN
# 3   115_exceptional points_quantum phase transitio...
# 4   189_coherent states_number coherent states_num...
# 5                                                 NaN
# 6   115_exceptional points_quantum phase transitio...
# 7   189_coherent states_number coherent states_num...
# 8                                                 NaN
# 9                                                 NaN
# 10  202_holomorphic sections_random holomorphic se...
# 11                                                NaN
# 12  115_exceptional points_quantum phase transitio...
#
#                                                 title  \
# 0                                                 NaN
# 1   The Complex Geometry and Representation Theory...
# 2                                                 NaN
# 3                      Symmetry in HartreeFock Theory
# 4   Complexified coherent states and quantum evolu...
# 5                                                 NaN
# 6   Energy Observable for a Quantum System with a ...
# 7   Nonclassical behaviour of coherent states for ...
# 8                                                 NaN
# 9                                                 NaN
# 10  Universality results for zeros of random holom...
# 11                                                NaN
# 12  Quantum phase transitions in nonhermitian harm...
#
#                                               summary
# 0                                                 NaN
# 1     Given a measure space , we can construct a n...
# 2                                                 NaN
# 3     symmetry  invariance with respect to combine...
# 4     The complex geometry underlying the Schr\"od...
# 5                                                 NaN
# 6     A nonHermitian operator may serve as the Ham...
# 7     We construct the coherent states and Schr\"o...
# 8                                                 NaN
# 9                                                 NaN
# 10    In this work we prove an universality result...
# 11                                                NaN
# 12    The Stone theorem requires that in a physica...
